# %% [markdown]
# <a href="https://colab.research.google.com/github/chanar227/Mod2_Chana_Roth/blob/main/Chana_Roth_HW2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a function called minutes_to_hours_and_minutes()
#
# - Ask the user how many minutes they would like to calculate
# - convert minutes to hours and minutes (hint :  user // and % operands)
# - print how many hours and minutes can be extracted from the user's minutes entry
# - Call the function minutes_to_hours_and_minutes()

# %% [markdown]
# Rubric:
# 1. Comment every line of code up to 10%
#   - for variables comment on the same line with #
#   - for other lines of code comment above the line with #
#   - for the function user """ comments """ to describe what your function does
#   - use """ """ at the top of your code to give your name, purpose of the assignment
# 2. algorithm is correct up to 80%
# 3. posted to github up to %10 in your module2_FirstName_LastName repository in your assignments folder

# %%
"""
Chana Roth
Module 2 HW 2A - converting minutes to hours and minutes. - practice in learning how to create a function.
"""
# Out:
# '\nChana Roth\nModule 2 HW 2A - converting minutes to hours and minutes. - practice in learning how to create a function.\n'

# %%
def minutes_to_hours_and_minutes():
  """
  This function asks a user how many minutes (they write the number of minutes) they want to be calculate/converted into hours and minutes
  (function converts minutes into hours and remianing minutes into minutes). After the hours and minute results will be printed for user to see
  """
  # first ask user for amount of minutes. - use int(input("...")). See below
  minutes = int(input("How many minutes would you like to to convert into hours and minutes? ")) # This prompt will appear and user will fill out the desired number of minutes.
  hours = minutes // 60 # now include the formula for converting minutes into hours (basic division - make sure to use //to get whole numbers).
  remaining_minutes = minutes % 60  #now include another formula for the remaining minutes. Use a % to calculate leftover remainder whic are the remaing minute!

  #Now we need to make it neat and display the converted hours and minutes nicely by using print and f.
  print(f"Your {minutes} minutes is now converted into {hours} hours and {remaining_minutes} minutes.")

#name of funtion so program can run:
minutes_to_hours_and_minutes()
# Out:
# How many minutes would you like to to convert into hours and minutes? 135
# Your 135 minutes is now converted into 2 hours and 15 minutes.

# %%
#now if want to ask a different number lets say 289 minutes - just write name of function and run program. Or you can rerun program above.
minutes_to_hours_and_minutes()
# Out:
# How many minutes would you like to to convert into hours and minutes? 289
# Your 289 minutes is now converted into 4 hours and 49 minutes.
